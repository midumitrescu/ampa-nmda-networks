# %%
from iteration_7_one_compartment_step_input.scripts import show_initial_up_state_implementation

show_initial_up_state_implementation()
# Out:
# 2025-11-12 19:20:31.993 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:20:31.995 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:20:31.995 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999998 << 1? False
# 2025-11-12 19:20:31.995 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -48.05647841 mV
# WARNING    /home/md/Workspace/python/ampa-nmda-networks/src/iteration_7_one_compartment_step_input/one_compartment_under_step_input.py:233: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax_rates.set_ylim(lims)
#  [py.warnings]
# WARNING    /home/md/Workspace/python/ampa-nmda-networks/src/iteration_7_one_compartment_step_input/one_compartment_under_step_input.py:233: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax_rates.set_ylim(lims)
#  [py.warnings]
# 2025-11-12 19:24:02.733 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:24:02.734 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:24:02.735 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999999 << 1? False
# 2025-11-12 19:24:02.735 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -47.40677966 mV
# 2025-11-12 19:27:41.704 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:27:41.705 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:27:41.706 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999999 << 1? False
# 2025-11-12 19:27:41.706 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -46.73010381 mV
# 2025-11-12 19:31:14.226 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:31:14.227 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:31:14.227 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:31:14.228 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -46.02473498 mV
# 2025-11-12 19:34:56.328 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:34:56.329 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:34:56.329 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:34:56.330 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -45.28880866 mV
# 2025-11-12 19:38:32.558 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:38:32.559 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:38:32.559 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:38:32.560 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -44.5202952 mV
# 2025-11-12 19:42:11.169 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:42:11.169 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:42:11.170 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:42:11.170 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -43.71698113 mV
# 2025-11-12 19:45:49.426 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:45:49.428 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:45:49.428 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:45:49.428 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -42.87644788 mV
# 2025-11-12 19:49:32.025 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:49:32.026 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:49:32.027 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999999 << 1? False
# 2025-11-12 19:49:32.027 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -41.99604743 mV
# 2025-11-12 19:53:15.170 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:53:15.171 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:53:15.171 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.049999999999999996 << 1? False
# 2025-11-12 19:53:15.171 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -41.07287449 mV
# 2025-11-12 19:56:59.113 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 19:56:59.114 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 19:56:59.114 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999999 << 1? False
# 2025-11-12 19:56:59.115 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -40.10373444 mV
