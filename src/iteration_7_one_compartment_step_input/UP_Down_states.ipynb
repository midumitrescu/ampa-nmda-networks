# %%
from iteration_7_one_compartment_step_input.scripts import show_initial_up_state_implementation

show_initial_up_state_implementation()
# Out:
# 2025-11-17 14:34:34.439 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-17 14:34:34.440 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-17 14:34:34.441 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999998 << 1? False
# 2025-11-17 14:34:34.441 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -48.05647841 mV
# WARNING    /home/md/Workspace/python/ampa-nmda-networks/src/iteration_7_one_compartment_step_input/one_compartment_under_step_input.py:233: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax_rates.set_ylim(lims)
#  [py.warnings]
# ...

# %% [markdown]
# I then modeled Up Down states with NMDA input modelled after Wang 2002, [Probabilistic decision making by slow reverberation in cortical circuits](https://pubmed.ncbi.nlm.nih.gov/12467598/), as discussed in
