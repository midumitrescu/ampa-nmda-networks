# %%
from iteration_7_one_compartment_step_input.scripts import show_initial_up_state_implementation

show_initial_up_state_implementation()
# Out:
# 2025-11-12 18:51:06.601 | DEBUG    | Configuration:__init__:112 - Computed tau membrane = 25. ms, nu threshold = 2. kHz
# 2025-11-12 18:51:06.603 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:421 - Is diffusion approximation valid? sigma_e / g_e0 =0.04999999999999999 << 1? False
# 2025-11-12 18:51:06.604 | DEBUG    | Configuration:__check_is_diffusion_approximation_valid__:422 - Is diffusion approximation valid? sigma_i / g_i0 =0.04999999999999998 << 1? False
# 2025-11-12 18:51:06.606 | DEBUG    | Configuration:__init__:331 - Effective Reversal with included Poisson Rate -48.05647841 mV
