# %% [markdown]
# # Symptomatically understanding the model
#
# To do this, I think it is a good idea to look at models of different E/I balance level (g parameter, same as Brunnel) and have the exact same parameters.

# %%
2
# Out:
# 2
