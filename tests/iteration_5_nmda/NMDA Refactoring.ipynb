# %% [markdown]
# # NMDA Refactoring
#
# I did a mistake in the previous model. There was no way of configuring g_max. Unfortunately, I had modelled $x_\text{NMDA}$ and $s_\text{NMDA}$ as conductances.
#
# Basically, the equations modelled were:
